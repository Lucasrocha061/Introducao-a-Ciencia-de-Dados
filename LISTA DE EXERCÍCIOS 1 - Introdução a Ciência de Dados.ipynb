# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucasrocha061/Introducao-a-Ciencia-de-Dados/blob/main/LISTA%20DE%20EXERC%C3%8DCIOS%201%20-%20Introdu%C3%A7%C3%A3o%20a%20Ci%C3%AAncia%20de%20Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# ## **<center>Lista de Exercícios 1 - Python Express</center>**
#
#
# **<center>Introdução a Ciência de Dados</center>**
# ***
#
# <br>
#
# Segue uma lista de exercícios abordando o conteúdo inicial para a programação em Python.
#
# Cada exercício deve ser respondido em uma célula específica.
#
#
# 1) Elabore um código que imprima a mensagem *"Olá terráqueos!!"* na tela.
#
#
# 2) Elabore um código que peça um número e então mostre a mensagem: *"O número informado foi [número]."*
#
#
# 3) Elabore um código que peça dois números e imprima a soma.
#
#
# 4) Elabore um código que peça as 4 notas bimestrais e mostre a média.
#
# 5) Elabore um código que converta metros para centímetros.
#
#
# 6) Elabore um código que peça o raio de um círculo, calcule e mostre sua área.
#
# 7) Elabore um código que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.
#
#
# 8) Elabore um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês em uma mensagem amigável.
#
#
# 9) Elabore um código que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# ** Onde C = 5 * ((F-32) / 9)**.
#
#
# 10) Elabore um código que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
#
#
# 11) Elabore um código que peça 2 números inteiros e um número real. Calcule e mostre:
# * o produto do dobro do primeiro com metade do segundo .
# * a soma do triplo do primeiro com o terceiro.
# * o terceiro elevado ao cubo.
#
# 12) Elabore um código que receba os dados de entrada a altura de uma pessoa, e informe qual seria o peso ideal, usando a seguinte fórmula: (72.7*altura) - 58

# %%
# 1) Elabore um código que imprima a mensagem *"Olá terráqueos!!"* na tela.

print("Olá, terráqueos!!")
# Out:
# Olá, terráqueos!!

# %%
# 2) Elabore um código que peça um número e então mostre a mensagem: "O número informado foi [número]."
num = input("Digite um número: ")
print(f"O número informado foi {num}.")
# Out:
# Digite um número: 10
# O número informado foi 10.

# %%
# 3) Elabore um código que peça dois números e imprima a soma.
num1 = int(input("Digite um número: "))
num2 = int(input("Digite outro número: "))
soma = num1 + num2
print(f"A soma dos números é {soma}.")
# Out:
# Digite um número: 10
# Digite outro número: 10
# A soma dos números é 20.

# %%
# 4) Elabore um código que peça as 4 notas bimestrais e mostre a média.
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
nota4 = float(input("Digite a quarta nota: "))
media = (nota1 + nota2 + nota3 + nota4) / 4
print(f"\nA média das notas é {media:.1f}.")
# Out:
# Digite a primeira nota: 10
# Digite a segunda nota: 10
# Digite a terceira nota: 10
# Digite a quarta nota: 10
#
# A média das notas é 10.0.

# %%
# 5) Elabore um código que converta metros para centímetros.
metros = float(input("Digite um valor em metros: "))
centimetros = metros * 100
print(f"{metros} metros equivale a {centimetros:.2f} centímetros.")
# Out:
# Digite um valor em metros: 155
# 155.0 metros equivale a 15500.0 centímetros.

# %%
# 6) Elabore um código que peça o raio de um círculo, calcule e mostre sua área.
raio = float(input("Digite o raio do círculo: "))
area = 3.14 * (raio ** 2)
print(f"A área do círculo é {area:.2f}.")
# Out:
# Digite o raio do círculo: 10
# A área do círculo é 314.00.

# %%
# 7) Elabore um código que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.
lado = float(input("Digite o valor do lado do quadrado em metros: "))
area = lado * lado
print(f'\nO valor da área é: {area:.2f} m')
print(f'O dobro da área é: {area * 2:.2f} m')
# Out:
# Digite o valor do lado do quadrado em metros: 10
#
# O valor da área é: 100.00 m
# O dobro da área é: 200.00 m

# %%
# 8)Elabore um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês em uma mensagem amigável.
ganha_hora = float(input("Quanto você ganha por hora? "))
horas_trabalhadas = float(input("Quantas horas você trabalhou no mês? "))
salario = ganha_hora * horas_trabalhadas
print(f"\nSeu salário é de R$ {salario:.2f}.")
# Out:
# Quanto você ganha por hora? 10
# Quantas horas você trabalhou no mês? 176
#
# Seu salário é de R$ 1760.00.

# %%
# 9) Elabore um código que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius. ** Onde C = 5 * ((F-32) / 9)**.
fahrenheit = float(input("Digite a temperatura em Fahrenheit: "))
celsius = 5 * ((fahrenheit - 32) / 9)
print(f"\nA temperatura em Celsius é {celsius:.2f}°C.")
# Out:
# Digite a temperatura em Fahrenheit: 20
#
# A temperatura em Celsius é -6.67°C.

# %%
# 10) Elabore um código que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
celsius = float(input("Digite a temperatura em Celsius: "))
fahrenheit = (celsius * 9 / 5) + 32
print(f"\nA temperatura em Fahrenheit é {fahrenheit}°F.")
# Out:
# Digite a temperatura em Celsius: -6.67
#
# A temperatura em Fahrenheit é 19.994°F.

# %%
# 11) Elabore um código que peça 2 números inteiros e um número real. Calcule e mostre:

# o produto do dobro do primeiro com metade do segundo.
num1 = int(input("Digite um número inteiro: "))
num2 = int(input("Digite outro número inteiro: "))
produto = (num1 * 2) * (num2 / 2)
print(f"\nO produto do dobro do primeiro com metade do segundo é {produto}.")
# Out:
# Digite um número inteiro: 10
# Digite outro número inteiro: 10
#
# O produto do dobro do primeiro com metade do segundo é 100.0.

# %%
# a soma do triplo do primeiro com o terceiro.
num1 = int(input("Digite um número inteiro: "))
num3 = float(input("Digite um número real: "))
soma = (num1 * 3) + num3
print(f"\nA soma do triplo do primeiro com o terceiro é {soma:.2f}.")
# Out:
# Digite um número inteiro: 10
# Digite um número real: 10
#
# A soma do triplo do primeiro com o terceiro é 40.0.

# %%
# o terceiro elevado ao cubo.
num3 = float(input("Digite um número real: "))
cubo = num3 ** 3
print(f"\nO terceiro elevado ao cubo é {cubo:.2f}.")
# Out:
# Digite um número real: 2
#
# O terceiro elevado ao cubo é 8.00.

# %%
 # 12) Elabore um código que receba os dados de entrada a altura de uma pessoa, e informe qual seria o peso ideal, usando a seguinte fórmula: (72.7*altura) - 58

# %%
altura = float(input("Digite o valor da sua altura em metros."))
peso_ideal = (72.7 * altura) -58
print(f"O seu peso ideal é: {peso_ideal:.2f} kg")
# Out:
# Digite o valor da sua altura em metros.1.75
# O seu peso ideal é: 69.23 kg
