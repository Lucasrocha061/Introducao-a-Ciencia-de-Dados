# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucasrocha061/Introducao-a-Ciencia-de-Dados/blob/main/Introdu%C3%A7%C3%A3o_a_An%C3%A1lise_de_Dados_com_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução a Análise de Dados com Python
#
# ##### Referência Bibliográfica:
# * **Python for Data Analysis,** Wes McKinney, O'Reilly Media

# %% [markdown]
# O objetivo deste material é apresentar os conceitos básicos para o início dos estudos sobre análise de dados utilizando a linguagem de programação Python.
#
# A primeira pergunta que surge é:
#
# - Por quê **Python**??
#
# Desde sua primeira aparição em 1991, o Python se tornou uma das linguagens de programação dinâmicas ou de script mais populares, juntamente com Perl, Ruby e outros.
#
# Dentre essa classe de linguagens, o Python se distingue pela grande e ativa comunidade de computação científica.
# Essa adoção vem aumentando significativamente desde o início dos anos 2000.
#
# Em análise de dados (tanto de visualização ou exploratória), sempre haverá a comparação do Python com outras linguagens e ferramentas comerciais de amplo uso como o **R**, **MATLAB**, **SAS**, **Stata** e outros.
#
# Leituras recomendadas:
#
# - https://medium.com/datadriveninvestor/top-6-data-science-programming-languages-for-2019-39ba1b6819a8
# - https://insights.dice.com/2019/03/01/best-programming-language-data-science/
# - https://towardsdatascience.com/python-vs-r-choosing-the-best-programming-languages-for-data-science-b1327f01f6bf
#
# Fatores de sucesso para a adoção do Python como principal linguagem de programação para a Ciência de Dados:
#
# **Grande comunidade** –  Dúvidas podem ser sanadas facilmente com pesquisas em fórums e sites especializados (https://stackoverflow.com/ é o principal deles)
#
# **Crescente número de bibliotecas de análise de dados** – Grande variedade bibliotecas de Ciência de dados (como por exemplo: *NumPy*, *SciPy*, *StatsModels*, *scikit-learn*, *pandas*, etc.), que estão em crescimento exponencial.
#
# **Curva de aprendizado** – O aprendizado é, consensualmente, rápido. A linguagem foi projetada para ser simples.
#
# ### Bibliotecas utilizadas
#
# - **numpy**: principal biblioteca para computação científica em Python. Fornece várias operações e recursos matemáticos.
# - **pandas**: fornece estruturas de dados e funções projetadas para o trabalho com dados estruturados.
# - **matplotLib**: biblioteca mais popular para a produção de gráficos e outras visualizações de dados em 2D.
# - **scikit learn**: utilizada para a implementação de modelos de data mining.
#
# ### Jupyter Notebook
#
# É um ambiente computacional web para criação de documentos para a plataforma Jupyter. O termo "notebook" pode, dependendo do contexto, fazer referência a entidades distintas como Jupyter (aplicativo Web), Jupyter Python (servidor Web) ou ao formato de documento para a plataforma. Um documento Jupyter Notebook é estruturado formato JSON, contendo uma lista ordenada de células de entrada / saída que podem conter código, texto (usando Markdown), matemática, gráficos e texto enriquecido, geralmente terminando com a extensão ".ipynb".
#
# ***Instalação e execução***
#
# A forma mais simples de acessar e utilizar um **Jupyter Notebook** é utilizando o ambiente **Google Colab**, que atua integrado ao Google Drive e oferece recursos bem generosos de computação.
#
# Para a utilização local, a maneira recomendada é instalar a distribuição [*Anaconda*](https://www.anaconda.com/).
#
# Após a instalação, para rodar o **Jupyter Notebook** basta digitar na linha de comando:
#
# `jupyter notebook`
#
# ou clicar no ícone do **Jupyter Notebook** na pasta de instalação da Anaconda. Uma aba com a pasta padrão do **Jupyter Notebook** se abrirá no navegador padrão. Para parar o **Jupyter Notebook** deve-se fechar o terminal que abriu em paralelo. Fechar apenas a aba não impede a continuidade da execução.
#
# Para criar um novo notebook, clicar em **New** (botão superior direito) e escolher qual a linguagem do novo notebook.
#
# Os comandos básicos podem ser encontrados na opção **"Help>Keyboard Shortcuts"** do menu.
#
# Para consultar a sintaxe Markdown, utilizada nas células de texto, clicar [aqui](https://docs.pipz.com/central-de-ajuda/learning-center/guia-basico-de-markdown#open).

# %% [markdown]
# #### Comandos mais utilizados:
# * Executar uma célula (**Ctrl + Enter**)
# * Criar uma célula acima  (**A**)
# * Criar uma célula abaixo  (**B**)
# * Deletar uma célula (**D, D**)
# * Executar todas as células do notebook (**Ctrl + A. Ctrl + Enter**)
#
# #### IMPORTANTE: Esses 5 comandos são aceitos quando a célula está no chamado modo comando que pode ser identificado pela cor da borda da célula... Deve ser azul.

# %% [markdown]
# # Entrada e saída de dados:

# %%
# Vamos começar escrevendo um texto
# Uma string pode ser escrita em python utilizando '', "", '''''', """"""
# Está sendo realizada uma saída de dados
print('Oi, meu nome é ')

# %%
print('Hello World!!!')
# Out:
# Hello World!!!

# %%
print("Olá, Lucas de Lima Rocha\n"'100,200,300')
# Out:
# Olá, Lucas de Lima Rocha
# 100,200,300

# %%
# Para entrada de dados
input("Qual o seu nome? ")
# Out:
# Qual o seu nome? Lucas
# 'Lucas'

# %%
# Vamos criar uma variável para guardar o nome?!
nome = input("Qual o seu nome? ")
# Out:
# Qual o seu nome? Lucas

# %%
#nome = 22
nome = Lucas

# %%
# Agora que guardamos o valor em uma variável, podemos reutilizá-la
print(nome)
# Out:
# Lucas

# %% [markdown]
# ## **Vamos praticar!!**

# %% [markdown]
# #### **Exercício 1**
#
# Escreva um código para exibir a mensagem "Olá, Mundo!"

# %%
# O comando abaixo vai imprimir na tela o texto "Olá, mundo!!!"
print('Hello World!!!')
# Out:
# Hello World!!!

# %% [markdown]
# #### **Exercício 2**
#
# Escreva um código para obter o nome e idade do usuário.

# %%
# Comando para receber valor externo
nome_usuario = input("Digite seu nome: ")
idade_usuario = input("Digite sua idade: ")
# Out:
# Digite seu nome: Lucas
# Digite sua idade: 18

# %% [markdown]
# #### **Exercício 3**
# Escreva um código para exibir o nome e idade do usuário obtidos no exercício anterior.

# %%
#print("O usuário "+nome_usuario+" tem "+idade_usuario+" anos.")
nome_usuario = input("Digite seu nome: ")
idade_usuario = input("Digite sua idade: ")
print("O usuário "+nome_usuario+" tem "+idade_usuario+" anos.")
# Out:
# Digite seu nome: Lucas
# Digite sua idade: 18
# O usuário Lucas tem 18 anos.

# %%
# Variação
#print("O usuário",nome_usuario,"tem",idade_usuario,"anos.")
nome_usuario = input("Digite seu nome: ")
idade_usuario = input("Digite sua idade: ")
print("O usuário",nome_usuario,"tem",idade_usuario,"anos.")
# Out:
# Digite seu nome: Lucas
# Digite sua idade: 18
# O usuário Lucas tem 18 anos.

# %%
# Variação
#print("O usuário {} tem {} anos de vida.".format(nome_usuario, idade_usuario))
nome_usuario = input("Digite seu nome: ")
idade_usuario = input("Digite sua idade: ")
print("O usuário {} tem {} anos de vida.".format(nome_usuario, idade_usuario))
# Out:
# Digite seu nome: Lucas
# Digite sua idade: 18
# O usuário Lucas tem 18 anos de vida.

# %%
# Outra variação... Usando o padrão "f-strings" - RECOMENDADA
#print(f"O usuário {nome_usuario} tem {idade_usuario} anos.")
nome_usuario = input("Digite seu nome: ")
idade_usuario = input("Digite sua idade: ")
print(f"O usuário {nome_usuario} tem {idade_usuario} anos.")
# Out:
# Digite seu nome: Lucas
# Digite sua idade: 18
# O usuário Lucas tem 18 anos.

# %% [markdown]
# # Operações básicas

# %%
8 + 4
# Out:
# 12

# %%
'8' + '4'
# Out:
# '84'

# %%
8 * '4'
# Out:
# '44444444'

# %%
type(8)
# Out:
# int

# %%
type('8')
# Out:
# str

# %%
"Introdução " + "ao Python"
# Out:
# 'Introdução ao Python'

# %%
'Introdução ' + "ao Python"
# Out:
# 'Introdução ao Python'

# %%
"Introdução" +  " " + "a Ciência" + " "+ "de" + " "+ "Dados"
# Out:
# 'Introdução a Ciência de Dados'

# %%
print("Introdução","a Ciência","de","Dados")
# Out:
# Introdução a Ciência de Dados

# %%
"Introdução a Ciência de Dados"
# Out:
# 'Introdução a Ciência de Dados'

# %% [markdown]
# # Atribuição de variáveis

# %%
a = 5
b = 6
x = 9

# %%
receita = 10750.42
despesa_variavel = 2178
despesa_fixa = 5763.90

lucro = receita - (despesa_variavel + despesa_fixa)

round(lucro, 2)   #ou print(lucro)
# Out:
# 2808.52

# %%
print("=== CALCULADORA ===")
print("\nEscolha uma operação:\n")
print("1 - Soma")
print("2 - Subtração")
print("3 - Multiplicação")
print("4 - Divisão")
print("5 - Porcentagem")
print("6 - Porcentagem de Porcentagem")

op = input("\nDigite o número da operação: ")

# Soma
if op == "1":
    a = float(input("Digite o primeiro número: "))
    b = float(input("Digite o segundo número: "))
    print("Resultado:", a + b)

# Subtração
elif op == "2":
    a = float(input("Digite o primeiro número: "))
    b = float(input("Digite o segundo número: "))
    print("Resultado:", a - b)

# Multiplicação
elif op == "3":
    a = float(input("Digite o primeiro número: "))
    b = float(input("Digite o segundo número: "))
    print("Resultado:", a * b)

# Divisão
elif op == "4":
    a = float(input("Digite o primeiro número: "))
    b = float(input("Digite o segundo número: "))

    if b == 0:
        print("Erro: divisão por zero.")
    else:
        print("Resultado:", a / b)

# Porcentagem
elif op == "5":
    valor = float(input("Digite o valor: "))
    porcentagem = float(input("Digite a porcentagem (%): "))

    resultado = valor * (porcentagem / 100)
    round("Resultado:", resultado, 2)

# Porcentagem de porcentagem
elif op == "6":
    p1 = float(input("Digite a primeira porcentagem (%): "))
    p2 = float(input("Digite a segunda porcentagem (%): "))

    resultado = (p1 / 100) * (p2 / 100) * 100
    round("Resultado:", resultado, "%",2)

else:
    print("Operação inválida.")
# Out:
# === CALCULADORA ===
#
# Escolha uma operação:
#
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Porcentagem
# 6 - Porcentagem de Porcentagem
#
# Digite o número da operação: 6
# Digite a primeira porcentagem (%): 100
# Digite a segunda porcentagem (%): 55
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_157/82304082.py in <cell line: 0>()
#      52
#      53     resultado = (p1 / 100) * (p2 / 100) * 100
# ---> 54     round("Resultado:", resultado, "%",2)
#      55
#      56 else:
#
# TypeError: round() takes at most 2 arguments (4 given)
